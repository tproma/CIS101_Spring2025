# %%
n = 984593656
if n % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Even

# %%
n = 389463757
if n > 0:
  print("Positive")
elif n==0 :
  print("Neutral")
else:
  print("Negative")
# Out:
# Positive
