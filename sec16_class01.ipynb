# %% [markdown]
# **This is our 1st class.**
# ###Python

# %%
print("Proma")
# Out:
# Proma

# %%
print('Proma')
# Out:
# Proma

# %%
print('''sdkjfgksudgf s
flkghkdfgjkdhfkgh
      dfhgdhfgjdf

      dfkgydkfgyydfsdgfsdkjfhkjxdfh''')
# Out:
# sdkjfgksudgf s
# flkghkdfgjkdhfkgh
#       dfhgdhfgjdf
#
#       dfkgydkfgyydfsdgfsdkjfhkjxdfh

# %%
a = 5
print("a")
# Out:
# a

# %%
a = 5
print(a)
# Out:
# 5

# %%
proma = 5
print(proma)
# Out:
# 5

# %%
proma = "Tanjina Proma"
print(proma)
# Out:
# Tanjina Proma

# %%
print(proma)
# Out:
# Tanjina Proma

# %%
student_id = 1234
course_name = "CSC101"

print(student_id, course_name)
# Out:
# 1234 CSC101

# %%
a = 3
b = 5

print(a,b)
# Out:
# 3 5

# %%
a = 3
b = 5

print("a:",a," b:",b)
print("a:",a,"; b:",b)
print("a=== ",a,";   b===",b)
# Out:
# a: 3  b: 5
# a: 3 ; b: 5
# a===  3 ;   b=== 5

# %%
a = 7
b = 8.91
c = 'Jonny Jonny Yes Pappa'
d = '34.4'
e = 4+3j
f = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
a = input("Enter a: ")
print("a:", a)
# Out:
# Enter a: 7345
# a: 7345

# %%
a = input("Enter a: ")
b = input("Enter b: ")

c = a+b
print("c = ", c)
# Out:
# Enter a: 3
# Enter b: 7
# c =  37

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))

c = a+b
print("c = ", c)
# Out:
# Enter a: 3
# Enter b: 7
# c =  10
