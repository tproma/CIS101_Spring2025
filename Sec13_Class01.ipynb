# %% [markdown]
# **This is our 1st class. **

# %%
print("Tanjina")
# Out:
# Tanjina

# %%
print("dfhslkdughsdghusdrhtuiy")
# Out:
# dfhslkdughsdghusdrhtuiy

# %%
print("sdjfgsjkdfjsg")
print("a")
print("aaaaaaa")
# Out:
# sdjfgsjkdfjsg
# a
# aaaaaaa

# %%
print('''dfgjdgjdj
sjdfgsdgfksgdfkgsk
      ksjdfjsgdfkgsdkg''')
# Out:
# dfgjdgjdj
# sjdfgsdgfksgdfkgsk
#       ksjdfjsgdfkgsdkg

# %%
print('jdfgdjgf')
# Out:
# jdfgdjgf

# %%
a = 5
print(a)
print("a")
# Out:
# 5
# a

# %%
proma = 2354734
print(proma)
# Out:
# 2354734

# %%
proma = "Tanjina proma"
print(proma)
# Out:
# Tanjina proma

# %%
print(proma)
# Out:
# Tanjina proma

# %%
id = "2012123"
print(id)
# Out:
# 2012123

# %%
student_id = 1234
course_name = "CSC101"

print(student_id, course_name)
# Out:
# 1234 CSC101

# %%
a = 5
b = 7
print(a, b)
# Out:
# 5 7

# %%
a = 5
b = 7
print("a:" ,a, "; b:", b)
# Out:
# a: 5 ; b: 7

# %%
a = 7
b = 8.91
c = 'Jonny Jonny Yes Pappa'
d = '34.4'
z = 3+6j

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'complex'>
